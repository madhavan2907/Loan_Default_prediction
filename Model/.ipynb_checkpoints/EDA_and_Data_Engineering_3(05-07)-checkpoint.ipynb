# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_rows = 85
pd.options.display.max_columns = 85

# %%
data = pd.read_table('XYZCorp_LendingData.txt', sep='\t')
print(data.shape)
data.head(3)
# Out:
# (855969, 73)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
#
#    int_rate  installment grade sub_grade emp_title emp_length home_ownership  \
# 0     10.65       162.87     B        B2       NaN  10+ years           RENT
# 1     15.27        59.83     C        C4     Ryder   < 1 year           RENT
# 2     15.96        84.33     C        C5       NaN  10+ years           RENT
#
#    annual_inc verification_status   issue_d pymnt_plan  \
# 0     24000.0            Verified  Dec-2011          n
# 1     30000.0     Source Verified  Dec-2011          n
# 2     12252.0        Not Verified  Dec-2011          n
#
#                                                 desc         purpose  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 855969 entries, 0 to 855968
# Data columns (total 73 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           855969 non-null  int64
#  1   member_id                    855969 non-null  int64
#  2   loan_amnt                    855969 non-null  float64
#  3   funded_amnt                  855969 non-null  float64
#  4   funded_amnt_inv              855969 non-null  float64
#  5   term                         855969 non-null  object
#  6   int_rate                     855969 non-null  float64
#  7   installment                  855969 non-null  float64
#  8   grade                        855969 non-null  object
#  9   sub_grade                    855969 non-null  object
#  10  emp_title                    806526 non-null  object
#  11  emp_length                   812908 non-null  object
# ...

# %% [markdown]
# Notes:
# term - months to be removed and convert the data to int

# %% [markdown]
# # Data Understanding and Preprocessing

# %%
print(data.shape)
# #id's- remove - id, member_id
# #Term
# # Stripping the months from term and converting dtype to float - no missing data
# # data.term = data.term.str.strip('months').astype('float64')
# print(type(data.term[0]))

# #Grade and Sub_grade - Ordinal data, shd do ordinal encoding - no missing data
# print('\n')
# print(np.sort(data.grade.unique()))
# print(np.sort(data.sub_grade.unique()))

# #Emp Title - 5.7% missing
# print('\n')
# print(data.emp_title.unique())

# #Emp length - 5.03% missing - shd do some king of ordinal encoding
# print('\n')
# print(data.emp_length.unique())

# #home_ownership - no missing data
# print('\n')
# print(data.home_ownership.unique())

# #annual_inc- no missing data

# #verification_status - no missing data - ordinal encoding
# print('\n')
# print(data.verification_status.unique())

# #issue_d - no missing data - need to chk if it's important 
# print('\n')
# print(data.issue_d.unique())

# #pymnt_plan - no missing data - ordinal encoding
# print('\n')
# print(data.pymnt_plan.unique())

# #desc - doesn't seem to be important so let's remove it
# print('\n')
# data.drop(labels=['desc'], axis=1, inplace=True)
# print(data.shape)

# #purpose - no missing data - looks like nominal data - have to chk if it hasd any relationship 
# #use this field to find any new inference at last
# print('\n')
# print(np.sort(data.purpose.unique()))


# #title - has 0.003% missing data - doesn't seem important - have to chk
# print('\n')
# print(data.title.unique())

# #zip_code - no missing data - doesn't seem important - have to chk
# print('\n')
# print(data.zip_code.unique())

# #addr_state - no missing data - doesn't seem important - have to chk
# print('\n')
# print(data.addr_state.unique())

#dti & dti_joint - no missing data

# # delinq_2yrs
# print('\n')
# print(data.delinq_2yrs.unique())

# # earliest_cr_line - no missing data - doesn't seem important - have to chk
# print('\n')
# print(np.count_nonzero(data.earliest_cr_line.unique()))


# # inq_last_6mths - no missing data, ;et's keep it as it is
# print('\n')
# print(np.sort(data.inq_last_6mths.unique()))

# # mths_since_last_delinq - has 51.3% missing data - needs missing value treatment
# print('\n')
# print(np.sort(data.mths_since_last_delinq.unique()))

#mths_since_last_record - has 84.6% missing data - not having entry for this field is better - have to chk more
#https://books.google.co.in/books?id=gWSCDwAAQBAJ&pg=PT66&dq=months+since+last_record&hl=en&sa=X&ved=2ahUKEwinr9mskanqAhVYfH0KHfTaBf8Q6AEwAHoECAYQAg#v=onepage&q=months%20since%20last_record&f=false

# # open_acc - The number of open credit lines in the borrower's credit file. - no missing data - lets keep it as it s
# print('\n')
# print(np.sort(data.open_acc.unique()))

# #pub_rec - Number of derogatory public records - no missing data - lets keep the data as it is - less is better
# print('\n')
# print(np.sort(data.pub_rec.unique()))

# #revol_bal - Total credit revolving balance - No missing data - lesser the better
# print(data.revol_bal.isna().sum())

# #total_acc - Line of Credit - No missing data
# print(data.total_acc.isna().sum())

# #initial_list_status - no missing data - nominal or ordinal shd works as it's binary - have to chk
# print('\n')
# print(np.sort(data.initial_list_status.unique()))

# # out_prncp / out_prncp_inv /total_pymnt /total_pymnt_inv / total_rec_prncp / total_rec_prncp /
# total_rec_int / total_rec_late_fee - no missing data
# print(data.out_prncp.isna().sum())
# print(data.out_prncp_inv.isna().sum())
# print(data.total_pymnt.isna().sum())
# print(data.total_pymnt_inv.isna().sum())
# print(data.total_rec_prncp.isna().sum())
# print(data.total_rec_int.isna().sum())
# print(data.total_rec_late_fee.isna().sum())

# # recoveries - post charge off gross recovery - no missing data
# print(data.recoveries.isna().sum())

#collection_recovery_fee - No missing data
#last_pymnt_d - 1.03% missing data - have to chk with the tgt variable
#last_pymnt_amnt - No missing data
#next_pymnt_d - 29.55% missing data - have to chk if it has any relationship with the tgt variable
#last_credit_pull_d - 0.005% missing data - have to chk if it has any relationship with the tgt variable
#collections_12_mths_ex_med - 0.006% missing data - have to chk if it's important

#mths_since_last_major_derog  - 75% missing data - need to chk if Nan can be filled as 0

# # policy_code - no missing data - doesn't seem to be important as only value is 1 - will chk the correlation
# print(data.policy_code.value_counts())

# #application_type - no missing data
# print(data.application_type.value_counts())
# print(data.application_type.isna().sum())
#annual_inc_joint - 99.94% missing data - good to drop

# # dti_joint/verification_status_joint - 99.9% missing data - good to drop
# # acc_now_delinq - no missing data
# print(data.acc_now_delinq.isna().sum())
# print(data.acc_now_delinq.value_counts())

# #  tot_coll_amt - 98.44% missing data  - good to drop

# # tot_cur_bal - 7.86% missing data
# print(data.tot_cur_bal.isna().sum())
# print(data.tot_cur_bal.value_counts())

# # open_acc_6m/open_il_6m/open_il_12m/open_il_24m/open_rv_12m/open_rv_24m/mths_since_rcnt_il/total_bal_il/max_bal_bc/all_util 
# # inq_fi/total_cu_tl/inq_last_12m- 98.44% missing data - good to drop

# # il_util = 98.6% missing data - good to drop

# # total_rev_hi_lim - 7.86% missing data

# # default_ind
# print(data.default_ind.isna().sum())
# print(data.default_ind.value_counts())
# Out:
# (855969, 73)

# %% [markdown]
# Missing Data estimation and computing

# %%
def missing_data_estimator(data):
    missing = pd.DataFrame(data.isna().sum().sort_values())
    missing.columns=['Count']
    missing = missing[missing.Count != 0]
    # missing = missing[missing.Count > 734157]       
    missing['Missing_Percentage'] = missing.Count/data.shape[0]*100
    print(missing)
    try :
        missing.Missing_Percentage.plot(kind='bar',figsize=(10,6))
    except:
        print('There is no missing data, Good to proceed further')

missing_data_estimator(data)
# Out:
#                               Count  Missing_Percentage
# title                            33            0.003855
# last_credit_pull_d               50            0.005841
# collections_12_mths_ex_med       56            0.006542
# revol_util                      446            0.052105
# last_pymnt_d                   8862            1.035318
# emp_length                    43061            5.030673
# emp_title                     49443            5.776261
# total_rev_hi_lim              67313            7.863953
# tot_coll_amt                  67313            7.863953
# tot_cur_bal                   67313            7.863953
# next_pymnt_d                 252971           29.553757
# mths_since_last_delinq       439812           51.381767
# mths_since_last_major_derog  642830           75.099682
# mths_since_last_record       724785           84.674211
# desc                         734157           85.769111
# total_cu_tl                  842681           98.447607
# ...

# %% [markdown]
# ### Removing features that has more than 84% of missing data and saving it as csv file

# %%
print('Shape b4 dropping the insignificant features : ', data.shape)
data_new = data.drop(labels=['desc','total_cu_tl','inq_fi','all_util','max_bal_bc','open_rv_24m','open_rv_12m','open_il_12m','open_il_24m','open_il_6m','open_acc_6m','inq_last_12m','total_bal_il','mths_since_rcnt_il','il_util','annual_inc_joint','verification_status_joint','dti_joint'], axis=1)
data_new.to_csv('Data_new_1.csv')
print('File is written to Local successfully')
print('Shape before import: ',data_new.shape)
data_new = pd.read_csv('Data_new_1.csv')
data_new.drop(labels='Unnamed: 0', axis=1, inplace=True) #removing the 1st col that was added while writing the csv file in prev step
print('Shape after import: ',data_new.shape)
data_new.head()
# Out:
# Shape b4 dropping the insignificant features :  (855969, 73)
# File is written to Local successfully
# Shape before import:  (855969, 55)
# Shape after import:  (855969, 55)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
# 3  1076863    1277178    10000.0      10000.0          10000.0   36 months
# 4  1075358    1311748     3000.0       3000.0           3000.0   60 months
#
#    int_rate  installment grade sub_grade                 emp_title emp_length  \
# 0     10.65       162.87     B        B2                       NaN  10+ years
# 1     15.27        59.83     C        C4                     Ryder   < 1 year
# 2     15.96        84.33     C        C5                       NaN  10+ years
# ...

# %%
# will rerun the missing_data_estimator() function on new data to see if those features having huge missing data is removed
missing_data_estimator(data_new)
# Out:
#                               Count  Missing_Percentage
# title                            33            0.003855
# last_credit_pull_d               50            0.005841
# collections_12_mths_ex_med       56            0.006542
# revol_util                      446            0.052105
# last_pymnt_d                   8862            1.035318
# emp_length                    43061            5.030673
# emp_title                     49443            5.776261
# total_rev_hi_lim              67313            7.863953
# tot_coll_amt                  67313            7.863953
# tot_cur_bal                   67313            7.863953
# next_pymnt_d                 252971           29.553757
# mths_since_last_delinq       439812           51.381767
# mths_since_last_major_derog  642830           75.099682
# mths_since_last_record       724785           84.674211

# %%
#Checking the correlation for the features having missing data with the target variable
a = data.loc[:,['title','last_credit_pull_d','collections_12_mths_ex_med','revol_util','last_pymnt_d','emp_length','emp_title','total_rev_hi_lim','tot_coll_amt','tot_cur_bal','next_pymnt_d','mths_since_last_delinq','mths_since_last_major_derog','mths_since_last_record','default_ind']]
a.head()
print('Shape before removing the missing values: ',a.shape)

a= a.dropna()
print('Shape after removing the missing values: ',a.shape)

sns.heatmap(a.corr(),vmin = -1, vmax = 1, center = 0, annot=True, fmt ='.1g')
a.corr()['default_ind'].sort_values()
# Out:
# Shape before removing the missing values:  (855969, 15)
# Shape after removing the missing values:  (28562, 15)
# mths_since_last_delinq        -0.010086
# tot_coll_amt                  -0.006916
# mths_since_last_major_derog   -0.006201
# total_rev_hi_lim              -0.003908
# tot_cur_bal                   -0.001528
# collections_12_mths_ex_med    -0.001300
# revol_util                     0.003529
# mths_since_last_record         0.003643
# default_ind                    1.000000
# Name: default_ind, dtype: float64

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28562 entries, 39753 to 855960
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   title                        28562 non-null  object
#  1   last_credit_pull_d           28562 non-null  object
#  2   collections_12_mths_ex_med   28562 non-null  float64
#  3   revol_util                   28562 non-null  float64
#  4   last_pymnt_d                 28562 non-null  object
#  5   emp_length                   28562 non-null  object
#  6   emp_title                    28562 non-null  object
#  7   total_rev_hi_lim             28562 non-null  float64
#  8   tot_coll_amt                 28562 non-null  float64
#  9   tot_cur_bal                  28562 non-null  float64
#  10  next_pymnt_d                 28562 non-null  object
#  11  mths_since_last_delinq       28562 non-null  float64
# ...

# %%
#Function to chk the significance for the Categorical variables:
def check_cat_relation(x,y,confidence_interval):
    from scipy.stats import chi2_contingency,chi2
    cross_table = pd.crosstab(x,y,margins=True)
    stat,p,dof,expected = chi2_contingency(cross_table)
    print("Chi_Square Value = {0}".format(stat))
    print("P-Value = {0}".format(p))
    alpha = 1 - confidence_interval
    
    if p > alpha:
        print(">> Accepting Null Hypothesis <<")
        print("There Is No Relationship Between Two Variables")
    else:
        print(">> Rejecting Null Hypothesis <<")
        print("There Is A Significance Relationship Between Two Variables")

#Function to chk the value counts:
def Unique_value_counts(data):
    value_counts = pd.DataFrame({'Field' : data.columns})
    value_counts['Counts'] = 0
    for i in range(len(value_counts.Field)):
        value_counts.iloc[i,1] = len(data.iloc[:,i].value_counts())
    value_counts.sort_values(by=['Counts'], inplace=True)
    return value_counts

# %%
a.columns
# Out:
# Index(['title', 'last_credit_pull_d', 'collections_12_mths_ex_med',
#        'revol_util', 'last_pymnt_d', 'emp_length', 'emp_title',
#        'total_rev_hi_lim', 'tot_coll_amt', 'tot_cur_bal', 'next_pymnt_d',
#        'mths_since_last_delinq', 'mths_since_last_major_derog',
#        'mths_since_last_record', 'default_ind'],
#       dtype='object')

# %%
a.corr()['default_ind'].sort_values()
# ALl these variables has no significance with the Target variable, hence it's better to be dropped
# Out:
# mths_since_last_delinq        -0.010086
# tot_coll_amt                  -0.006916
# mths_since_last_major_derog   -0.006201
# total_rev_hi_lim              -0.003908
# tot_cur_bal                   -0.001528
# collections_12_mths_ex_med    -0.001300
# revol_util                     0.003529
# mths_since_last_record         0.003643
# default_ind                    1.000000
# Name: default_ind, dtype: float64

# %%
# Using data instead of a just to avoid wrong interprettation based on the limited data
print('--------------------------title--------------------------')
check_cat_relation(a.default_ind,a.title,0.95)
print('--------------------------last_credit_pull_d--------------------------')
check_cat_relation(data.default_ind,data.last_credit_pull_d,0.95)
print('--------------------------last_pymnt_d--------------------------')
check_cat_relation(data.default_ind,data.last_pymnt_d,0.95)
print('--------------------------emp_length--------------------------')
check_cat_relation(data.default_ind,data.emp_length,0.95)
# Out:
# --------------------------title--------------------------
# Chi_Square Value = 1547.5509597772152
# P-Value = 1.4424908660438303e-08
# >> Rejecting Null Hypothesis <<
# There Is A Significance Relationship Between Two Variables
# --------------------------last_credit_pull_d--------------------------
# Chi_Square Value = 63274.06998301559
# P-Value = 0.0
# >> Rejecting Null Hypothesis <<
# There Is A Significance Relationship Between Two Variables
# --------------------------last_pymnt_d--------------------------
# Chi_Square Value = 146358.29937551572
# P-Value = 0.0
# >> Rejecting Null Hypothesis <<
# There Is A Significance Relationship Between Two Variables
# --------------------------emp_length--------------------------
# Chi_Square Value = 472.1931767970126
# P-Value = 4.5123218902063356e-86
# >> Rejecting Null Hypothesis <<
# There Is A Significance Relationship Between Two Variables

# %% [markdown]
# Features to be retained based on the significant relation with the Target variable:
# title
# last_credit_pull_d
# last_pymnt_d
# emp_length

# %%
print('Shape b4 dropping the insignificant features : ', data_new.shape)
data_new = data_new.drop(labels=['mths_since_last_delinq','tot_coll_amt','mths_since_last_major_derog','total_rev_hi_lim','tot_cur_bal','collections_12_mths_ex_med','revol_util','mths_since_last_record'], axis=1)

data_new.to_csv('Data_new_2.csv')
print('File is written to Local successfully')
print('Shape before import: ',data_new.shape)
data_new = pd.read_csv('Data_new_2.csv')
data_new.drop(labels='Unnamed: 0', axis=1, inplace=True) #removing the 1st col that was added while writing the csv file in prev step
print('Shape after import: ',data_new.shape)
data_new.head()
# Out:
# Shape b4 dropping the insignificant features :  (855969, 55)
# File is written to Local successfully
# Shape before import:  (855969, 47)
# Shape after import:  (855969, 47)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
# 3  1076863    1277178    10000.0      10000.0          10000.0   36 months
# 4  1075358    1311748     3000.0       3000.0           3000.0   60 months
#
#    int_rate  installment grade sub_grade                 emp_title emp_length  \
# 0     10.65       162.87     B        B2                       NaN  10+ years
# 1     15.27        59.83     C        C4                     Ryder   < 1 year
# 2     15.96        84.33     C        C5                       NaN  10+ years
# ...

# %%
# will rerun the missing_data_estimator() function on new data to see if those features dropped in previous step is actually is removed
missing_data_estimator(data_new)
# Out:
#                      Count  Missing_Percentage
# title                   33            0.003855
# last_credit_pull_d      50            0.005841
# last_pymnt_d          8862            1.035318
# emp_length           43061            5.030673
# emp_title            49443            5.776261
# next_pymnt_d        252971           29.553757

# %%
#From this list we can impute missing values for emp_length, emp_title and next_pymnt_d alone and for the rest let's remove the rows having Na's
# as their missing pct is very less/negligible

# Instead of filling the missing values for these features with mode, i am going to fill it as 
# a new category called 'Unknown' to keep the authenticity of the data as it is

data_new.emp_length = data_new.emp_length.fillna("Unknown")
data_new.emp_length.value_counts().sort_values()

data_new.emp_title = data_new.emp_title.fillna("Unknown")
data_new.emp_title.value_counts().sort_values()

data_new.next_pymnt_d = data_new.next_pymnt_d.fillna("Unknown")
data_new.next_pymnt_d.value_counts().sort_values()
# Out:
# Mar-2016        66
# Jan-2016     68838
# Unknown     252971
# Feb-2016    534094
# Name: next_pymnt_d, dtype: int64

# %%
# will rerun the missing_data_estimator() function on new data to see if those features which has missing pct < 1% is alone present
missing_data_estimator(data_new)
# Out:
#                     Count  Missing_Percentage
# title                  33            0.003855
# last_credit_pull_d     50            0.005841
# last_pymnt_d         8862            1.035318

# %%
#Lets remove the rows where we have na's now as the count for the above features is very negligible when compared to whole datset
print('Shape before dropping na: ',data_new.shape)
data_new= data_new.dropna()
print('Shape after dropping na ',data_new.shape)

data_new.to_csv('Data_new_3.csv')
print('File is written to Local successfully')
print('Shape before import: ',data_new.shape)
data_new = pd.read_csv('Data_new_3.csv')
data_new.drop(labels='Unnamed: 0', axis=1, inplace=True) #removing the 1st col that was added while writing the csv file in prev step
print('Shape after import: ',data_new.shape)
data_new.head()
# Out:
# Shape before dropping na:  (855969, 47)
# Shape after dropping na  (847031, 47)
# File is written to Local successfully
# Shape before import:  (847031, 47)
# Shape after import:  (847031, 47)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
# 3  1076863    1277178    10000.0      10000.0          10000.0   36 months
# 4  1075358    1311748     3000.0       3000.0           3000.0   60 months
#
#    int_rate  installment grade sub_grade                 emp_title emp_length  \
# 0     10.65       162.87     B        B2                   Unknown  10+ years
# 1     15.27        59.83     C        C4                     Ryder   < 1 year
# 2     15.96        84.33     C        C5                   Unknown  10+ years
# ...

# %%
# will rerun the missing_data_estimator() one last time to ensure we don't have any missing values now
missing_data_estimator(data_new)
# Out:
# Empty DataFrame
# Columns: [Count, Missing_Percentage]
# Index: []
# There is no missing data, Good to proceed further

# %% [markdown]
# ### Lets visualize the complete datset using sweetviz now for gaining more insights:

# %%
import sweetviz as sv
# my_report = sv.analyze([data_new,'df'], target_feat='default_ind')

# %%
# my_report.show_html("Report.html")

# %% [markdown]
# ### Data split-up to Numerical and categorical

# %%
numerics = ['int16','int32','int64','float16','float32','float64']
categories=['object']
data_num = data_new.select_dtypes(include=numerics)
print('shape of Numerical data : ',data_num.shape)
data_cat = data_new.select_dtypes(include=categories)
print('shape of Categorical data : ',data_cat.shape)
# Out:
# shape of Numerical data :  (847031, 28)
# shape of Categorical data :  (847031, 19)

# %%
# # ----------------- comment out this cell b4 running ----------------------

# # Skeleton to update the dtypes:
# # data_new[''] = data_new[''].astype('object')
# # data_new[''] = data_new[''].astype('float64')

print('Shape of num data before moving/altering features: ',data_num.shape)
print('Shape of cat data before moving/altering features: ',data_cat.shape)

#Removing the Id's -2 from num
data_new = data_new.drop(labels=['id','member_id'], axis=1 )

#Term - Stripping the months from term and converting dtype to float - no missing data -1 cat + num
data_new['term'] = data_new.term.str.strip('months').astype('float64')

# print('-----------------------------------------------')
# print(data_num.acc_now_delinq.value_counts())
# print('-----------------------------------------------')
# print(data_num.inq_last_6mths.value_counts())
# print('-----------------------------------------------')
# print(data_num.delinq_2yrs.value_counts())
# print('-----------------------------------------------')
# print(data_num.default_ind.value_counts())
# print('-----------------------------------------------')
# print(data_num.pub_rec.value_counts())

# # Since above features are categories, converting them to categ from num
# # policy_code/acc_now_delinq/inq_last_6mths/delinq_2yrs/default_ind/pub_rec : -6 from num and +6 to cat
data_new['policy_code'] = data_new['policy_code'].astype('object')
data_new['acc_now_delinq'] = data_new['acc_now_delinq'].astype('object')
data_new['inq_last_6mths'] = data_new['inq_last_6mths'].astype('object')
data_new['delinq_2yrs'] = data_new['delinq_2yrs'].astype('object')
data_new['default_ind'] = data_new['default_ind'].astype('object')
data_new['pub_rec'] = data_new['pub_rec'].astype('object')

data_num = data_new.select_dtypes(include=numerics)
data_cat = data_new.select_dtypes(include=categories)

print('Shape after moving/altering features: ',data_num.shape)
print('Shape of cat data after moving/altering features: ',data_cat.shape)
# Out:
# Shape of num data before moving/altering features:  (847031, 28)
# Shape of cat data before moving/altering features:  (847031, 19)
# Shape after moving/altering features:  (847031, 21)
# Shape of cat data after moving/altering features:  (847031, 24)

# %% [markdown]
# --> id's- remove - id, member_id
# --> Term Stripping the months from term - no missing data
# --> Grade and Sub_grade - Ordinal data, shd do ordinal encoding - no missing data
# --> Emp Title - 5.7% missing
# --> Emp length - 5.03% missing - shd do some king of ordinal encoding
# --> home_ownership - no missing data
# --> annual_inc- no missing data
# --> verification_status - no missing data - ordinal encoding
# --> issue_d - no missing data - need to chk if it's important
# --> pymnt_plan - no missing data - ordinal encoding
# --> desc - doesn't seem to be important so let's remove it
# --> purpose - no missing data - looks like nominal data - have to chk if it hasd any relationship  - use this field to find any new inference at last
# --> title - has 0.003% missing data - doesn't seem important - have to chk
# --> zip_code - no missing data - doesn't seem important - have to chk
# --> addr_state - no missing data - doesn't seem important - have to chk
# --> dti & dti_joint - no missing data
# --> delinq_2yrs
# -->  earliest_cr_line - no missing data - doesn't seem important - have to chk
# --> inq_last_6mths - no missing data, ;et's keep it as it is
# --> mths_since_last_delinq - has 51.3% missing data - needs missing value treatment
# --> mths_since_last_record - has 84.6% missing data - not having entry for this field is better - have to chk more
# https://books.google.co.in/books?id=gWSCDwAAQBAJ&pg=PT66&dq=months+since+last_record&hl=en&sa=X&ved=2ahUKEwinr9mskanqAhVYfH0KHfTaBf8Q6AEwAHoECAYQAg#v=onepage&q=months%20since%20last_record&f=false
# --> pub_rec - Number of derogatory public records - no missing data - lets keep the data as it is - less is better
# --> revol_bal - Total credit revolving balance - No missing data - lesser the better
# --> total_acc - Line of Credit - No missing data
# --> initial_list_status - no missing data - nominal or ordinal shd works as it's binary - have to chk
# --> out_prncp / out_prncp_inv /total_pymnt /total_pymnt_inv / total_rec_prncp / total_rec_prncp /
# --> total_rec_int / total_rec_late_fee - no missing data
# --> recoveries - post charge off gross recovery - no missing data
# -->  collection_recovery_fee - No missing data
# -->  last_pymnt_d - 1.03% missing data - have to chk with the tgt variable
# -->  last_pymnt_amnt - No missing data
# --> next_pymnt_d - 29.55% missing data - have to chk if it has any relationship with the tgt variable
# --> last_credit_pull_d - 0.005% missing data - have to chk if it has any relationship with the tgt variable
# --> collections_12_mths_ex_med - 0.006% missing data - have to chk if it's important
# --> mths_since_last_major_derog  - 75% missing data - need to chk if Nan can be filled as 0
# --> policy_code - no missing data - doesn't seem to be important as only value is 1 - will chk the correlation
# --> application_type - no missing data
# --> annual_inc_joint - 99.94% missing data - good to drop
# --> dti_joint/verification_status_joint - 99.9% missing data - good to drop
# --> acc_now_delinq - no missing data
# --> tot_coll_amt - 98.44% missing data  - good to drop
# --> tot_cur_bal - 7.86% missing data
# --> open_acc_6m/open_il_6m/open_il_12m/open_il_24m/open_rv_12m/open_rv_24m/mths_since_rcnt_il/total_bal_il/max_bal_bc/all_util
# --> inq_fi/total_cu_tl/inq_last_12m- 98.44% missing data - good to drop
# --> il_util = 98.6% missing data - good to drop
# --> total_rev_hi_lim - 7.86% missing data
# --> default_ind

# %%
Unique_value_counts(data_cat)
# Out:
#                   Field  Counts
# 20          policy_code       1
# 23          default_ind       2
# 21     application_type       2
# 16  initial_list_status       2
# 7            pymnt_plan       2
# 5   verification_status       3
# 18         next_pymnt_d       4
# 4        home_ownership       6
# 0                 grade       7
# 22       acc_now_delinq       8
# 14       inq_last_6mths       9
# 3            emp_length      12
# 8               purpose      14
# 12          delinq_2yrs      29
# 15              pub_rec      30
# 1             sub_grade      35
# 11           addr_state      51
# 17         last_pymnt_d      97
# 19   last_credit_pull_d     102
# 6               issue_d     103
# 13     earliest_cr_line     697
# 10             zip_code     930
# 9                 title   60928
# 2             emp_title  288924

# %% [markdown]
# # Now let's check the significant categorical variables with the target variable:

# %%
# Findining significant Numerical Features with respect to the target variable
# Let's add the target variable to data_num df to chk the correlation and then will remove it finally
data_num['Target'] = data_cat['default_ind'].astype('float64')
# data_num.head()
print(data_num.corr()['Target'].sort_values())
plt.figure(figsize=(18,12))
sns.heatmap(data_num.corr(), vmin=-1, vmax=1, annot=True)
data_num.drop(labels = 'Target', axis = 1, inplace=True)
# Out:
# out_prncp                 -0.224839
# out_prncp_inv             -0.224837
# total_rec_prncp           -0.090964
# last_pymnt_amnt           -0.087681
# total_pymnt_inv           -0.040740
# total_pymnt               -0.039722
# annual_inc                -0.037027
# open_acc                  -0.020864
# total_acc                 -0.020519
# revol_bal                 -0.020263
# funded_amnt_inv           -0.007288
# funded_amnt               -0.004972
# loan_amnt                 -0.004077
# dti                        0.004885
# installment                0.005393
# term                       0.031983
# total_rec_int              0.046738
# total_rec_late_fee         0.141619
# int_rate                   0.154403
# collection_recovery_fee    0.330887
# recoveries                 0.477281
# Target                     1.000000
# Name: Target, dtype: float64

# %%
# # Running Boruta using Random Forest algo 

# x_train = data_num
# y_train = data_cat.default_ind.astype('float64')
# from boruta import BorutaPy
# from sklearn.ensemble import RandomForestClassifier
# import numpy as np
# ###initialize Boruta
# forest = RandomForestClassifier(n_estimators=1000, n_jobs=-1, class_weight='balanced')
# boruta = BorutaPy(estimator = forest, n_estimators = 'auto', verbose=2,  max_iter = 10) # number of trials to perform

# ### fit Boruta (it accepts np.array, not pd.DataFrame, 
# ### Alternative is while seperating DV and IDV itself get the values alone using .values to get arrays)
# boruta.fit(np.array(x_train),np.array(y_train))
# ### print results
# green_area = x_train.columns[boruta.support_].to_list()
# blue_area = x_train.columns[boruta.support_weak_].to_list()
# print('Significant Features:', green_area)
# print('Partially significant Features:', blue_area)

# %% [markdown]
# Output of previous cell:
#
# ![image.png](attachment:image.png)

# %%
# # Running Boruta using XG-Boost algo 

# x_train = data_num
# y_train = data_cat.default_ind.astype('float64')
# from boruta import BorutaPy
# from xgboost import XGBClassifier
# import numpy as np
# ###initialize Boruta
# xg  = XGBClassifier(n_estimators=1000, n_jobs=-1, class_weight='balanced')
# boruta = BorutaPy(estimator = forest, n_estimators = 'auto', verbose=2,  max_iter = 10) # number of trials to perform

# ### fit Boruta (it accepts np.array, not pd.DataFrame, 
# ### Alternative is while seperating DV and IDV itself get the values alone using .values to get arrays)
# boruta.fit(np.array(x_train),np.array(y_train))
# ### print results
# green_area = x_train.columns[boruta.support_].to_list()
# blue_area = x_train.columns[boruta.support_weak_].to_list()
# print('Significant Features:', green_area)
# print('Partially significant Features:', blue_area)

# %%
data_num.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'annual_inc', 'dti', 'open_acc', 'revol_bal',
#        'total_acc', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_amnt'],
#       dtype='object')

# %% [markdown]
# Output of previous cell:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Lets drop the insig features from data_new and re-assign the data_num and also save them locally in a file

# %%
print('Shape b4 dropping insignificant variable: ',data_num.shape)
data_new.drop(labels=['open_acc','total_acc'], inplace=True, axis=1)

#It's very important to reassign the data_num/cat with the updated data_new records
data_num = data_new.select_dtypes(include=numerics)
data_cat = data_new.select_dtypes(include=categories)
print('Shape after dropping insignificant variable: ',data_num.shape)
data_num.to_csv('Significant_Numerical_features.csv')
print('File is written to Local successfully')
print('Shape b4 import: ',data_num.shape)
data_num=pd.read_csv('Significant_Numerical_features.csv')
data_num.drop(labels='Unnamed: 0', axis=1, inplace=True) #removing the 1st col that was added while writing the csv file in prev step
print('Shape after import: ',data_num.shape)
# Out:
# Shape b4 dropping insignificant variable:  (847031, 21)
# Shape after dropping insignificant variable:  (847031, 19)
# File is written to Local successfully
# Shape b4 import:  (847031, 19)
# Shape after import:  (847031, 19)

# %%
Unique_value_counts(data_cat)
# Out:
#                   Field  Counts
# 20          policy_code       1
# 23          default_ind       2
# 21     application_type       2
# 16  initial_list_status       2
# 7            pymnt_plan       2
# 5   verification_status       3
# 18         next_pymnt_d       4
# 4        home_ownership       6
# 0                 grade       7
# 22       acc_now_delinq       8
# 14       inq_last_6mths       9
# 3            emp_length      12
# 8               purpose      14
# 12          delinq_2yrs      29
# 15              pub_rec      30
# 1             sub_grade      35
# 11           addr_state      51
# 17         last_pymnt_d      97
# 19   last_credit_pull_d     102
# 6               issue_d     103
# 13     earliest_cr_line     697
# 10             zip_code     930
# 9                 title   60928
# 2             emp_title  288924

# %%
# data_cat.title.str.contains('Debt').value_counts()
#handling the title feature and reducing it to fewer chunks of categories to see if it's significant feature or not in next step
#Eventhough this is similiar to purpose, just keeping it for now
data_new.loc[data_new.title.str.contains('Debt|debt|loan'),'title'] = 'Debt_consolidations'
data_new.loc[data_new.title.str.contains('Home|home'),'title'] = 'Home_expenses'
data_new.loc[data_new.title.str.contains('Credit|credit|card'),'title'] = 'Credit_card_expenses'
data_new.loc[data_new.title.str.contains('Medical|medical'),'title'] = 'Medical_expenses'
data_new.loc[data_new.title.str.contains('Major|major'),'title'] = 'Major_purchases'
data_new.loc[~data_new.title.str.contains('Home_expenses|Debt_consolidations|Medical_expenses|Credit_card_expenses|Major_purchases'),'title'] = 'Other_expenses'

#It's very important to reassign the data_num/cat with the updated data_new records
data_num = data_new.select_dtypes(include=numerics)
data_cat = data_new.select_dtypes(include=categories)
data_cat.title.value_counts()
# Out:
# Debt_consolidations     456055
# Credit_card_expenses    184087
# Other_expenses          139667
# Home_expenses            47684
# Major_purchases          12012
# Medical_expenses          7526
# Name: title, dtype: int64

# %%
Unique_value_counts(data_cat)
# Out:
#                   Field  Counts
# 20          policy_code       1
# 23          default_ind       2
# 21     application_type       2
# 16  initial_list_status       2
# 7            pymnt_plan       2
# 5   verification_status       3
# 18         next_pymnt_d       4
# 4        home_ownership       6
# 9                 title       6
# 0                 grade       7
# 22       acc_now_delinq       8
# 14       inq_last_6mths       9
# 3            emp_length      12
# 8               purpose      14
# 12          delinq_2yrs      29
# 15              pub_rec      30
# 1             sub_grade      35
# 11           addr_state      51
# 17         last_pymnt_d      97
# 19   last_credit_pull_d     102
# 6               issue_d     103
# 13     earliest_cr_line     697
# 10             zip_code     930
# 2             emp_title  288924

# %%
cols = list(data_cat.columns)

cols.remove('default_ind')
cols.remove('emp_title')

for i in (cols):
    print ('Checking relation between : ',i + ' and default_ind' )
    check_cat_relation(data_cat[i], data_cat.default_ind, 0.95)
    print('-------------------------------------------------------------')
# Out:
# Checking relation between :  grade and default_ind
# Chi_Square Value = 13135.446071981545
# P-Value = 0.0
# >> Rejecting Null Hypothesis <<
# There Is A Significance Relationship Between Two Variables
# -------------------------------------------------------------
# Checking relation between :  sub_grade and default_ind
# Chi_Square Value = 14057.414962222698
# P-Value = 0.0
# >> Rejecting Null Hypothesis <<
# There Is A Significance Relationship Between Two Variables
# -------------------------------------------------------------
# Checking relation between :  emp_length and default_ind
# Chi_Square Value = 486.5250731746409
# P-Value = 1.0425642669453382e-87
# >> Rejecting Null Hypothesis <<
# There Is A Significance Relationship Between Two Variables
# -------------------------------------------------------------
# Checking relation between :  home_ownership and default_ind
# Chi_Square Value = 1078.756476800977
# P-Value = 2.1643641991550277e-223
# ...

# %% [markdown]
# #### Significant Features
#
# Checking relation between :  grade and default_ind
# There Is A Significance Relationship Between Two Variables
#
# Checking relation between :  sub_grade and default_ind
# There Is A Significance Relationship Between Two Variables
#
# Checking relation between :  emp_length and default_ind
# There Is A Significance Relationship Between Two Variables
#
# Checking relation between :  home_ownership and default_ind
# There Is A Significance Relationship Between Two Variables
#
# Checking relation between :  verification_status and default_ind
# There Is A Significance Relationship Between Two Variables
#
# Checking relation between :  issue_d and default_ind
# There Is A Significance Relationship Between Two Variables
#
# Checking relation between :  purpose and default_ind
# There Is A Significance Relationship Between Two Variables
#
# Checking relation between :  zip_code and default_ind
# There Is A Significance Relationship Between Two Variables
#
# Checking relation between :  addr_state and default_ind
# There Is A Significance Relationship Between Two Variables
#
# Checking relation between :  delinq_2yrs and default_ind
# There Is A Significance Relationship Between Two Variables
#
# Checking relation between :  earliest_cr_line and default_ind
# There Is A Significance Relationship Between Two Variables
#
# Checking relation between :  inq_last_6mths and default_ind
# There Is A Significance Relationship Between Two Variables
#
# Checking relation between :  title and default_ind
# There Is A Significance Relationship Between Two Variables
#
# Checking relation between :  pub_rec and default_ind
# There Is A Significance Relationship Between Two Variables
#
# Checking relation between :  initial_list_status and default_ind
# There Is A Significance Relationship Between Two Variables
#
# Checking relation between :  last_pymnt_d and default_ind
# There Is A Significance Relationship Between Two Variables
#
# Checking relation between :  next_pymnt_d and default_ind
# There Is A Significance Relationship Between Two Variables
#
# Checking relation between :  last_credit_pull_d and default_ind
# There Is A Significance Relationship Between Two Variables
#
# Checking relation between :  application_type and default_ind
# There Is A Significance Relationship Between Two Variables
#
#
#
# #### Insignificant Features
# Checking relation between :  policy_code and default_ind
# There Is No Relationship Between Two Variables
#
# Checking relation between :  pymnt_plan and default_ind
# There Is No Relationship Between Two Variables
#
# Checking relation between :  acc_now_delinq and default_ind
# There Is No Relationship Between Two Variables

# %% [markdown]
# #### Lets re-assign the data_num only with the significant variables and also save them locally in a file

# %%
print('Shape b4 dropping insignificant variable: ',data_cat.shape)
# removing emp_title, do try again later by adding them
data_new.drop(labels=['policy_code','pymnt_plan','acc_now_delinq','emp_title'], axis=1, inplace=True) 

#It's very important to reassign the data_num/cat with the updated data_new records
data_num = data_new.select_dtypes(include=numerics)
data_cat = data_new.select_dtypes(include=categories)

print('Shape after dropping insignificant variable: ',data_cat.shape)
data_cat.to_csv('Significant_Categorical_features.csv')
print('File is written to Local successfully')
print('Shape b4 import: ',data_cat.shape)
data_cat=pd.read_csv('Significant_Categorical_features.csv')
data_cat.drop(labels='Unnamed: 0', axis=1, inplace=True) #removing the 1st col that was added while writing the csv file in prev step
print('Shape after import: ',data_cat.shape)
# Out:
# Shape b4 dropping insignificant variable:  (847031, 24)
# Shape after dropping insignificant variable:  (847031, 20)
# File is written to Local successfully
# Shape b4 import:  (847031, 20)
# Shape after import:  (847031, 20)

# %%
Unique_value_counts(data_cat)
# Out:
#                   Field  Counts
# 19          default_ind       2
# 14  initial_list_status       2
# 18     application_type       2
# 4   verification_status       3
# 16         next_pymnt_d       4
# 3        home_ownership       6
# 7                 title       6
# 0                 grade       7
# 12       inq_last_6mths       9
# 2            emp_length      12
# 6               purpose      14
# 10          delinq_2yrs      29
# 13              pub_rec      30
# 1             sub_grade      35
# 9            addr_state      51
# 15         last_pymnt_d      97
# 17   last_credit_pull_d     102
# 5               issue_d     103
# 11     earliest_cr_line     697
# 8              zip_code     930

# %% [markdown]
# # Labeling Categorical variables

# %% [markdown]
# Strategy:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Cleaning and aggregating categories

# %%
# # Data cleaning

#verification_status - per data dict 
# print(data_new.verification_status.value_counts())
data_new.loc[data_new.verification_status.str.contains('Not Verified|OTHER'),'verification_status'] = '0'
data_new.loc[data_new.verification_status.str.contains('Source Verified'),'verification_status'] = '1'
data_new.loc[data_new.verification_status.str.contains('Verified'),'verification_status'] = '2'
data_new.verification_status = data_new.verification_status.astype('float64')
#It's very important to reassign the data_num/cat with the updated data_new records
data_num = data_new.select_dtypes(include=numerics)
data_cat = data_new.select_dtypes(include=categories)
# print(data_new.verification_status.value_counts())
# print(type(data_new.verification_status[0])) # checking for 1 element else it returns as pandas.series as type

#home_ownership - Per excel,Our values are: RENT, OWN, MORTGAGE, OTHER so replacing other categories with Other
data_new.loc[data_new.home_ownership.str.contains('NONE|ANY'),'home_ownership'] = 'OTHER'
data_new.home_ownership.value_counts()
#It's very important to reassign the data_num/cat with the updated data_new records
data_num = data_new.select_dtypes(include=numerics)
data_cat = data_new.select_dtypes(include=categories)

#grade - A - 1 | B - 2 | C - 3 | D - 4 | E -5 | F - 6 | G -7
# print(data_new.grade.value_counts())
data_new.loc[data_new.grade.str.contains('A'),'grade'] = '1'
data_new.loc[data_new.grade.str.contains('B'),'grade'] = '2'
data_new.loc[data_new.grade.str.contains('C'),'grade'] = '3'
data_new.loc[data_new.grade.str.contains('D'),'grade'] = '4'
data_new.loc[data_new.grade.str.contains('E'),'grade'] = '5'
data_new.loc[data_new.grade.str.contains('F'),'grade'] = '6'
data_new.loc[data_new.grade.str.contains('G'),'grade'] = '7'
data_new.grade = data_new.grade.astype('float64')
#It's very important to reassign the data_num/cat with the updated data_new records
data_num = data_new.select_dtypes(include=numerics)
data_cat = data_new.select_dtypes(include=categories)
# print(data_new.grade.value_counts())
# print(type(data_new.grade[0])) # checking for 1 element else it returns as pandas.series as type

#emp_length
# print(data_new.emp_length.value_counts())
data_new.loc[data_new.emp_length.str.contains('Unknown'),'emp_length'] = '0'
data_new.loc[data_new.emp_length.str.contains('1 year|1 years'),'emp_length'] = '1'
data_new.loc[data_new.emp_length.str.contains('2 years'),'emp_length'] = '2'
data_new.loc[data_new.emp_length.str.contains('3 years'),'emp_length'] = '3'
data_new.loc[data_new.emp_length.str.contains('4 years'),'emp_length'] = '4'
data_new.loc[data_new.emp_length.str.contains('5 years'),'emp_length'] = '5'
data_new.loc[data_new.emp_length.str.contains('6 years'),'emp_length'] = '6'
data_new.loc[data_new.emp_length.str.contains('7 years'),'emp_length'] = '7'
data_new.loc[data_new.emp_length.str.contains('8 years'),'emp_length'] = '8'
data_new.loc[data_new.emp_length.str.contains('9 years'),'emp_length'] = '9'
data_new.loc[data_new.emp_length.str.contains("10\+ years"),'emp_length'] = '10' #Don't fgt to put a '\' b4 +, else it won't work
data_new.emp_length = data_new.emp_length.astype('float64')
#It's very important to reassign the data_num/cat with the updated data_new records
data_num = data_new.select_dtypes(include=numerics)
data_cat = data_new.select_dtypes(include=categories)
# print(data_new.emp_length.value_counts())
# print(type(data_new.emp_length[0])) # checking for 1 element else it returns as pandas.series as type

#inq_last_6mths
data_new.inq_last_6mths = data_new.inq_last_6mths.astype('float64')
#It's very important to reassign the data_num/cat with the updated data_new records
data_num = data_new.select_dtypes(include=numerics)
data_cat = data_new.select_dtypes(include=categories)
# print(type(data_new.inq_last_6mths[0])) # checking for 1 element else it returns as pandas.series as type

# # #delinq_2yrs/pub_rec
data_new.delinq_2yrs = data_new.delinq_2yrs.astype('float64')
data_new.pub_rec = data_new.pub_rec.astype('float64')
#It's very important to reassign the data_num/cat with the updated data_new records
data_num = data_new.select_dtypes(include=numerics)
data_cat = data_new.select_dtypes(include=categories)
# print(type(data_new.delinq_2yrs[0])) # checking for 1 element else it returns as pandas.series as type
# print(type(data_new.pub_rec[0])) # checking for 1 element else it returns as pandas.series as type

#sub_grade - A - 1.1,2..5 | B - 2.1,2..5 | C - 3.1,2..5 | D - 4.1,2..5 | E -5.1,2..5 | F - 6.1,2..5 | G -7.1,2..5
# print(data_new.sub_grade.value_counts())
data_new.loc[data_new.sub_grade.str.contains('A1'),'sub_grade'] = '1.1'
data_new.loc[data_new.sub_grade.str.contains('A2'),'sub_grade'] = '1.2'
data_new.loc[data_new.sub_grade.str.contains('A3'),'sub_grade'] = '1.3'
data_new.loc[data_new.sub_grade.str.contains('A4'),'sub_grade'] = '1.4'
data_new.loc[data_new.sub_grade.str.contains('A5'),'sub_grade'] = '1.5'
data_new.loc[data_new.sub_grade.str.contains('B1'),'sub_grade'] = '2.1'
data_new.loc[data_new.sub_grade.str.contains('B2'),'sub_grade'] = '2.2'
data_new.loc[data_new.sub_grade.str.contains('B3'),'sub_grade'] = '2.3'
data_new.loc[data_new.sub_grade.str.contains('B4'),'sub_grade'] = '2.4'
data_new.loc[data_new.sub_grade.str.contains('B5'),'sub_grade'] = '2.5'
data_new.loc[data_new.sub_grade.str.contains('C1'),'sub_grade'] = '3.1'
data_new.loc[data_new.sub_grade.str.contains('C2'),'sub_grade'] = '3.2'
data_new.loc[data_new.sub_grade.str.contains('C3'),'sub_grade'] = '3.3'
data_new.loc[data_new.sub_grade.str.contains('C4'),'sub_grade'] = '3.4'
data_new.loc[data_new.sub_grade.str.contains('C5'),'sub_grade'] = '3.5'
data_new.loc[data_new.sub_grade.str.contains('D1'),'sub_grade'] = '4.1'
data_new.loc[data_new.sub_grade.str.contains('D2'),'sub_grade'] = '4.2'
data_new.loc[data_new.sub_grade.str.contains('D3'),'sub_grade'] = '4.3'
data_new.loc[data_new.sub_grade.str.contains('D4'),'sub_grade'] = '4.4'
data_new.loc[data_new.sub_grade.str.contains('D5'),'sub_grade'] = '4.5'
data_new.loc[data_new.sub_grade.str.contains('E1'),'sub_grade'] = '5.1'
data_new.loc[data_new.sub_grade.str.contains('E2'),'sub_grade'] = '5.2'
data_new.loc[data_new.sub_grade.str.contains('E3'),'sub_grade'] = '5.3'
data_new.loc[data_new.sub_grade.str.contains('E4'),'sub_grade'] = '5.4'
data_new.loc[data_new.sub_grade.str.contains('E5'),'sub_grade'] = '5.5'
data_new.loc[data_new.sub_grade.str.contains('F1'),'sub_grade'] = '6.1'
data_new.loc[data_new.sub_grade.str.contains('F2'),'sub_grade'] = '6.2'
data_new.loc[data_new.sub_grade.str.contains('F3'),'sub_grade'] = '6.3'
data_new.loc[data_new.sub_grade.str.contains('F4'),'sub_grade'] = '6.4'
data_new.loc[data_new.sub_grade.str.contains('F5'),'sub_grade'] = '6.5'
data_new.loc[data_new.sub_grade.str.contains('G1'),'sub_grade'] = '7.1'
data_new.loc[data_new.sub_grade.str.contains('G2'),'sub_grade'] = '7.2'
data_new.loc[data_new.sub_grade.str.contains('G3'),'sub_grade'] = '7.3'
data_new.loc[data_new.sub_grade.str.contains('G4'),'sub_grade'] = '7.4'
data_new.loc[data_new.sub_grade.str.contains('G5'),'sub_grade'] = '7.5'
data_new.sub_grade = data_new.sub_grade.astype('float64')
#It's very important to reassign the data_num/cat with the updated data_new records
data_num = data_new.select_dtypes(include=numerics)
data_cat = data_new.select_dtypes(include=categories)
# print(data_new.sub_grade.value_counts())
# print(type(data_new.sub_grade[0])) # checking for 1 element else it returns as pandas.series as type

# %% [markdown]
# Let's simplify the Addr feature my mapping the US states to Region level :
# ![image.png](attachment:image.png)

# %%
# # addr_state 
# print(data_new.sub_grade.value_counts())
data_new.loc[data_new.addr_state.str.contains('IL|IN|IA|KS|MI|MN|MO|NE|ND|OH|SD|WI'),'addr_state'] = 'Mid_west'
data_new.loc[data_new.addr_state.str.contains('CT|ME|MA|NH|NJ|NY|PA|RI|VT'),'addr_state'] = 'Nort_East'
data_new.loc[data_new.addr_state.str.contains('AL|AR|DC|DE|FL|GA|KY|LA|MD|MS|NC|OK|SC|TN|TX|VA|WV'),'addr_state'] = 'South'
data_new.loc[data_new.addr_state.str.contains('AK|AZ|CA|CO|HI|ID|MT|NV|NM|OR|UT|WA|WY'),'addr_state'] = 'West'
#It's very important to reassign the data_num/cat with the updated data_new records
data_num = data_new.select_dtypes(include=numerics)
data_cat = data_new.select_dtypes(include=categories)
# print(data_new.addr_state.value_counts())

# # zip_code
data_new.drop(labels='zip_code',axis=1, inplace=True)

#earliest_cr_line
data_new.loc[data_new.earliest_cr_line.str.contains('Jan-1944|Jan-1946|Aug-1946|Jan-1948|Jun-1949|Jan-1950|May-1950|Aug-1950|Oct-1950|Nov-1950|Dec-1950|Jan-1951|Jul-1951|Aug-1951|Dec-1951|Jan-1952|Jan-1953|May-1953|Sep-1953|Nov-1953|Jan-1954|Oct-1954|Nov-1954|Jan-1955|Mar-1955|Apr-1955|May-1955|Jun-1955|Jul-1955|Aug-1955|Nov-1955|Jan-1956|Sep-1956|Nov-1956|Dec-1956|Jan-1957|Feb-1957|May-1957|Jun-1957|Sep-1957|Oct-1957|Nov-1957|Jan-1958|Mar-1958|Apr-1958|May-1958|Jun-1958|Jul-1958|Aug-1958|Oct-1958|Nov-1958|Dec-1958|Jan-1959|Feb-1959|Mar-1959|May-1959|Jun-1959|Jul-1959|Aug-1959|Sep-1959|Oct-1959|Nov-1959|Dec-1959'),'earliest_cr_line'] = '1940-59'
data_new.loc[data_new.earliest_cr_line.str.contains('Jan-1960|Feb-1960|Mar-1960|Apr-1960|May-1960|Jun-1960|Jul-1960|Aug-1960|Sep-1960|Oct-1960|Nov-1960|Dec-1960|Jan-1961|Feb-1961|Mar-1961|Apr-1961|May-1961|Jun-1961|Jul-1961|Aug-1961|Sep-1961|Oct-1961|Nov-1961|Dec-1961|Jan-1962|Mar-1962|Apr-1962|May-1962|Jun-1962|Jul-1962|Aug-1962|Sep-1962|Oct-1962|Nov-1962|Dec-1962|Jan-1963|Feb-1963|Mar-1963|Apr-1963|May-1963|Jun-1963|Jul-1963|Aug-1963|Sep-1963|Oct-1963|Nov-1963|Dec-1963|Jan-1964|Feb-1964|Mar-1964|Apr-1964|May-1964|Jun-1964|Jul-1964|Aug-1964|Sep-1964|Oct-1964|Nov-1964|Dec-1964|Jan-1965|Feb-1965|Mar-1965|Apr-1965|May-1965|Jun-1965|Jul-1965|Aug-1965|Sep-1965|Oct-1965|Nov-1965|Dec-1965|Jan-1966|Feb-1966|Mar-1966|Apr-1966|May-1966|Jun-1966|Jul-1966|Aug-1966|Sep-1966|Oct-1966|Nov-1966|Dec-1966|Jan-1967|Feb-1967|Mar-1967|Apr-1967|May-1967|Jun-1967|Jul-1967|Aug-1967|Sep-1967|Oct-1967|Nov-1967|Dec-1967|Jan-1968|Feb-1968|Mar-1968|Apr-1968|May-1968|Jun-1968|Jul-1968|Aug-1968|Sep-1968|Oct-1968|Nov-1968|Dec-1968|Jan-1969|Feb-1969|Mar-1969|Apr-1969|May-1969|Jun-1969|Jul-1969|Aug-1969|Sep-1969|Oct-1969|Nov-1969|Dec-1969|Jan-1970|Feb-1970|Mar-1970|Apr-1970|May-1970|Jun-1970|Jul-1970|Aug-1970|Sep-1970|Oct-1970|Nov-1970|Dec-1970|Jan-1971|Feb-1971|Mar-1971|Apr-1971|May-1971|Jun-1971|Jul-1971|Aug-1971|Sep-1971|Oct-1971|Nov-1971|Dec-1971|Jan-1972|Feb-1972|Mar-1972|Apr-1972|May-1972|Jun-1972|Jul-1972|Aug-1972|Sep-1972|Oct-1972|Nov-1972|Dec-1972|Jan-1973|Feb-1973|Mar-1973|Apr-1973|May-1973|Jun-1973|Jul-1973|Aug-1973|Sep-1973|Oct-1973|Nov-1973|Dec-1973|Jan-1974|Feb-1974|Mar-1974|Apr-1974|May-1974|Jun-1974|Jul-1974|Aug-1974|Sep-1974|Oct-1974|Nov-1974|Dec-1974|Jan-1975|Feb-1975|Mar-1975|Apr-1975|May-1975|Jun-1975|Jul-1975|Aug-1975|Sep-1975|Oct-1975|Nov-1975|Dec-1975|Jan-1976|Feb-1976|Mar-1976|Apr-1976|May-1976|Jun-1976|Jul-1976|Aug-1976|Sep-1976|Oct-1976|Nov-1976|Dec-1976|Jan-1977|Feb-1977|Mar-1977|Apr-1977|May-1977|Jun-1977|Jul-1977|Aug-1977|Sep-1977|Oct-1977|Nov-1977|Dec-1977|Jan-1978|Feb-1978|Mar-1978|Apr-1978|May-1978|Jun-1978|Jul-1978|Aug-1978|Sep-1978|Oct-1978|Nov-1978|Dec-1978|Jan-1979|Feb-1979|Mar-1979|Apr-1979|May-1979|Jun-1979|Jul-1979|Aug-1979|Sep-1979|Oct-1979|Nov-1979|Dec-1979'),'earliest_cr_line'] = '1960-79'
data_new.loc[data_new.earliest_cr_line.str.contains('Jan-1980|Feb-1980|Mar-1980|Apr-1980|May-1980|Jun-1980|Jul-1980|Aug-1980|Sep-1980|Oct-1980|Nov-1980|Dec-1980|Jan-1981|Feb-1981|Mar-1981|Apr-1981|May-1981|Jun-1981|Jul-1981|Aug-1981|Sep-1981|Oct-1981|Nov-1981|Dec-1981|Jan-1982|Feb-1982|Mar-1982|Apr-1982|May-1982|Jun-1982|Jul-1982|Aug-1982|Sep-1982|Oct-1982|Nov-1982|Dec-1982|Jan-1983|Feb-1983|Mar-1983|Apr-1983|May-1983|Jun-1983|Jul-1983|Aug-1983|Sep-1983|Oct-1983|Nov-1983|Dec-1983|Jan-1984|Feb-1984|Mar-1984|Apr-1984|May-1984|Jun-1984|Jul-1984|Aug-1984|Sep-1984|Oct-1984|Nov-1984|Dec-1984|Jan-1985|Feb-1985|Mar-1985|Apr-1985|May-1985|Jun-1985|Jul-1985|Aug-1985|Sep-1985|Oct-1985|Nov-1985|Dec-1985|Jan-1986|Feb-1986|Mar-1986|Apr-1986|May-1986|Jun-1986|Jul-1986|Aug-1986|Sep-1986|Oct-1986|Nov-1986|Dec-1986|Jan-1987|Feb-1987|Mar-1987|Apr-1987|May-1987|Jun-1987|Jul-1987|Aug-1987|Sep-1987|Oct-1987|Nov-1987|Dec-1987|Jan-1988|Feb-1988|Mar-1988|Apr-1988|May-1988|Jun-1988|Jul-1988|Aug-1988|Sep-1988|Oct-1988|Nov-1988|Dec-1988|Jan-1989|Feb-1989|Mar-1989|Apr-1989|May-1989|Jun-1989|Jul-1989|Aug-1989|Sep-1989|Oct-1989|Nov-1989|Dec-1989|Jan-1990|Feb-1990|Mar-1990|Apr-1990|May-1990|Jun-1990|Jul-1990|Aug-1990|Sep-1990|Oct-1990|Nov-1990|Dec-1990|Jan-1991|Feb-1991|Mar-1991|Apr-1991|May-1991|Jun-1991|Jul-1991|Aug-1991|Sep-1991|Oct-1991|Nov-1991|Dec-1991|Jan-1992|Feb-1992|Mar-1992|Apr-1992|May-1992|Jun-1992|Jul-1992|Aug-1992|Sep-1992|Oct-1992|Nov-1992|Dec-1992|Jan-1993|Feb-1993|Mar-1993|Apr-1993|May-1993|Jun-1993|Jul-1993|Aug-1993|Sep-1993|Oct-1993|Nov-1993|Dec-1993|Jan-1994|Feb-1994|Mar-1994|Apr-1994|May-1994|Jun-1994|Jul-1994|Aug-1994|Sep-1994|Oct-1994|Nov-1994|Dec-1994|Jan-1995|Feb-1995|Mar-1995|Apr-1995|May-1995|Jun-1995|Jul-1995|Aug-1995|Sep-1995|Oct-1995|Nov-1995|Dec-1995|Jan-1996|Feb-1996|Mar-1996|Apr-1996|May-1996|Jun-1996|Jul-1996|Aug-1996|Sep-1996|Oct-1996|Nov-1996|Dec-1996|Jan-1997|Feb-1997|Mar-1997|Apr-1997|May-1997|Jun-1997|Jul-1997|Aug-1997|Sep-1997|Oct-1997|Nov-1997|Dec-1997|Jan-1998|Feb-1998|Mar-1998|Apr-1998|May-1998|Jun-1998|Jul-1998|Aug-1998|Sep-1998|Oct-1998|Nov-1998|Dec-1998|Jan-1999|Feb-1999|Mar-1999|Apr-1999|May-1999|Jun-1999|Jul-1999|Aug-1999|Sep-1999|Oct-1999|Nov-1999|Dec-1999'),'earliest_cr_line'] = '1980-99'
data_new.loc[data_new.earliest_cr_line.str.contains('Jan-2000|Feb-2000|Mar-2000|Apr-2000|May-2000|Jun-2000|Jul-2000|Aug-2000|Sep-2000|Oct-2000|Nov-2000|Dec-2000|Jan-2001|Feb-2001|Mar-2001|Apr-2001|May-2001|Jun-2001|Jul-2001|Aug-2001|Sep-2001|Oct-2001|Nov-2001|Dec-2001|Jan-2002|Feb-2002|Mar-2002|Apr-2002|May-2002|Jun-2002|Jul-2002|Aug-2002|Sep-2002|Oct-2002|Nov-2002|Dec-2002|Jan-2003|Feb-2003|Mar-2003|Apr-2003|May-2003|Jun-2003|Jul-2003|Aug-2003|Sep-2003|Oct-2003|Nov-2003|Dec-2003|Jan-2004|Feb-2004|Mar-2004|Apr-2004|May-2004|Jun-2004|Jul-2004|Aug-2004|Sep-2004|Oct-2004|Nov-2004|Dec-2004|Jan-2005|Feb-2005|Mar-2005|Apr-2005|May-2005|Jun-2005|Jul-2005|Aug-2005|Sep-2005|Oct-2005|Nov-2005|Dec-2005'),'earliest_cr_line'] = '2000-05'
data_new.loc[data_new.earliest_cr_line.str.contains('Jan-2006|Feb-2006|Mar-2006|Apr-2006|May-2006|Jun-2006|Jul-2006|Aug-2006|Sep-2006|Oct-2006|Nov-2006|Dec-2006|Jan-2007|Feb-2007|Mar-2007|Apr-2007|May-2007|Jun-2007|Jul-2007|Aug-2007|Sep-2007|Oct-2007|Nov-2007|Dec-2007|Jan-2008|Feb-2008|Mar-2008|Apr-2008|May-2008|Jun-2008|Jul-2008|Aug-2008|Sep-2008|Oct-2008|Nov-2008|Dec-2008|Jan-2009|Feb-2009|Mar-2009|Apr-2009|May-2009|Jun-2009|Jul-2009|Aug-2009|Sep-2009|Oct-2009|Nov-2009|Dec-2009|Jan-2010|Feb-2010|Mar-2010|Apr-2010|May-2010|Jun-2010|Jul-2010|Aug-2010|Sep-2010|Oct-2010|Nov-2010|Dec-2010'),'earliest_cr_line'] = '2006-10'
data_new.loc[data_new.earliest_cr_line.str.contains('Jan-2011|Feb-2011|Mar-2011|Apr-2011|May-2011|Jun-2011|Jul-2011|Aug-2011|Sep-2011|Oct-2011|Nov-2011|Dec-2011|Jan-2012|Feb-2012|Mar-2012|Apr-2012|May-2012|Jun-2012|Jul-2012|Aug-2012|Sep-2012|Oct-2012|Nov-2012'),'earliest_cr_line'] = '2011-15'
#It's very important to reassign the data_num/cat with the updated data_new records
data_num = data_new.select_dtypes(include=numerics)
data_cat = data_new.select_dtypes(include=categories)
# print(data_new.earliest_cr_line.value_counts())

# # last_pymnt_d
data_new.loc[data_new.last_pymnt_d.str.contains('Jan-2007|Feb-2007|Mar-2007'),'last_pymnt_d'] = 'Q1-2007'
data_new.loc[data_new.last_pymnt_d.str.contains('Apr-2007|May-2007|Jun-2007'),'last_pymnt_d'] = 'Q2-2007'
data_new.loc[data_new.last_pymnt_d.str.contains('Jul-2007|Aug-2007|Sep-2007'),'last_pymnt_d'] = 'Q3-2007'
data_new.loc[data_new.last_pymnt_d.str.contains('Oct-2007|Nov-2007|Dec-2007'),'last_pymnt_d'] = 'Q4-2007'
data_new.loc[data_new.last_pymnt_d.str.contains('Jan-2008|Feb-2008|Mar-2008'),'last_pymnt_d'] = 'Q1-2008'
data_new.loc[data_new.last_pymnt_d.str.contains('Apr-2008|May-2008|Jun-2008'),'last_pymnt_d'] = 'Q2-2008'
data_new.loc[data_new.last_pymnt_d.str.contains('Jul-2008|Aug-2008|Sep-2008'),'last_pymnt_d'] = 'Q3-2008'
data_new.loc[data_new.last_pymnt_d.str.contains('Oct-2008|Nov-2008|Dec-2008'),'last_pymnt_d'] = 'Q4-2008'
data_new.loc[data_new.last_pymnt_d.str.contains('Jan-2009|Feb-2009|Mar-2009'),'last_pymnt_d'] = 'Q1-2009'
data_new.loc[data_new.last_pymnt_d.str.contains('Apr-2009|May-2009|Jun-2009'),'last_pymnt_d'] = 'Q2-2009'
data_new.loc[data_new.last_pymnt_d.str.contains('Jul-2009|Aug-2009|Sep-2009'),'last_pymnt_d'] = 'Q3-2009'
data_new.loc[data_new.last_pymnt_d.str.contains('Oct-2009|Nov-2009|Dec-2009'),'last_pymnt_d'] = 'Q4-2009'
data_new.loc[data_new.last_pymnt_d.str.contains('Jan-2010|Feb-2010|Mar-2010'),'last_pymnt_d'] = 'Q1-2010'
data_new.loc[data_new.last_pymnt_d.str.contains('Apr-2010|May-2010|Jun-2010'),'last_pymnt_d'] = 'Q2-2010'
data_new.loc[data_new.last_pymnt_d.str.contains('Jul-2010|Aug-2010|Sep-2010'),'last_pymnt_d'] = 'Q3-2010'
data_new.loc[data_new.last_pymnt_d.str.contains('Oct-2010|Nov-2010|Dec-2010'),'last_pymnt_d'] = 'Q4-2010'
data_new.loc[data_new.last_pymnt_d.str.contains('Jan-2011|Feb-2011|Mar-2011'),'last_pymnt_d'] = 'Q1-2011'
data_new.loc[data_new.last_pymnt_d.str.contains('Apr-2011|May-2011|Jun-2011'),'last_pymnt_d'] = 'Q2-2011'
data_new.loc[data_new.last_pymnt_d.str.contains('Jul-2011|Aug-2011|Sep-2011'),'last_pymnt_d'] = 'Q3-2011'
data_new.loc[data_new.last_pymnt_d.str.contains('Oct-2011|Nov-2011|Dec-2011'),'last_pymnt_d'] = 'Q4-2011'
data_new.loc[data_new.last_pymnt_d.str.contains('Jan-2012|Feb-2012|Mar-2012'),'last_pymnt_d'] = 'Q1-2012'
data_new.loc[data_new.last_pymnt_d.str.contains('Apr-2012|May-2012|Jun-2012'),'last_pymnt_d'] = 'Q2-2012'
data_new.loc[data_new.last_pymnt_d.str.contains('Jul-2012|Aug-2012|Sep-2012'),'last_pymnt_d'] = 'Q3-2012'
data_new.loc[data_new.last_pymnt_d.str.contains('Oct-2012|Nov-2012|Dec-2012'),'last_pymnt_d'] = 'Q4-2012'
data_new.loc[data_new.last_pymnt_d.str.contains('Jan-2013|Feb-2013|Mar-2013'),'last_pymnt_d'] = 'Q1-2013'
data_new.loc[data_new.last_pymnt_d.str.contains('Apr-2013|May-2013|Jun-2013'),'last_pymnt_d'] = 'Q2-2013'
data_new.loc[data_new.last_pymnt_d.str.contains('Jul-2013|Aug-2013|Sep-2013'),'last_pymnt_d'] = 'Q3-2013'
data_new.loc[data_new.last_pymnt_d.str.contains('Oct-2013|Nov-2013|Dec-2013'),'last_pymnt_d'] = 'Q4-2013'
data_new.loc[data_new.last_pymnt_d.str.contains('Jan-2014|Feb-2014|Mar-2014'),'last_pymnt_d'] = 'Q1-2014'
data_new.loc[data_new.last_pymnt_d.str.contains('Apr-2014|May-2014|Jun-2014'),'last_pymnt_d'] = 'Q2-2014'
data_new.loc[data_new.last_pymnt_d.str.contains('Jul-2014|Aug-2014|Sep-2014'),'last_pymnt_d'] = 'Q3-2014'
data_new.loc[data_new.last_pymnt_d.str.contains('Oct-2014|Nov-2014|Dec-2014'),'last_pymnt_d'] = 'Q4-2014'
data_new.loc[data_new.last_pymnt_d.str.contains('Jan-2015|Feb-2015|Mar-2015'),'last_pymnt_d'] = 'Q1-2015'
data_new.loc[data_new.last_pymnt_d.str.contains('Apr-2015|May-2015|Jun-2015'),'last_pymnt_d'] = 'Q2-2015'
data_new.loc[data_new.last_pymnt_d.str.contains('Jul-2015|Aug-2015|Sep-2015'),'last_pymnt_d'] = 'Q3-2015'
data_new.loc[data_new.last_pymnt_d.str.contains('Oct-2015|Nov-2015|Dec-2015'),'last_pymnt_d'] = 'Q4-2015'
data_new.loc[data_new.last_pymnt_d.str.contains('Jan-2016|Feb-2016|Mar-2016'),'last_pymnt_d'] = 'Q1-2016'
data_new.loc[data_new.last_pymnt_d.str.contains('Apr-2016|May-2016|Jun-2016'),'last_pymnt_d'] = 'Q2-2016'
data_new.loc[data_new.last_pymnt_d.str.contains('Jul-2016|Aug-2016|Sep-2016'),'last_pymnt_d'] = 'Q3-2016'
data_new.loc[data_new.last_pymnt_d.str.contains('Oct-2016|Nov-2016|Dec-2016'),'last_pymnt_d'] = 'Q4-2016'
#It's very important to reassign the data_num/cat with the updated data_new records
data_num = data_new.select_dtypes(include=numerics)
data_cat = data_new.select_dtypes(include=categories)
# print(data_new.last_pymnt_d.value_counts())

# # last_credit_pull_d
data_new.loc[data_new.last_credit_pull_d.str.contains('Jan-2007|Feb-2007|Mar-2007'),'last_credit_pull_d'] = 'Q1-2007'
data_new.loc[data_new.last_credit_pull_d.str.contains('Apr-2007|May-2007|Jun-2007'),'last_credit_pull_d'] = 'Q2-2007'
data_new.loc[data_new.last_credit_pull_d.str.contains('Jul-2007|Aug-2007|Sep-2007'),'last_credit_pull_d'] = 'Q3-2007'
data_new.loc[data_new.last_credit_pull_d.str.contains('Oct-2007|Nov-2007|Dec-2007'),'last_credit_pull_d'] = 'Q4-2007'
data_new.loc[data_new.last_credit_pull_d.str.contains('Jan-2008|Feb-2008|Mar-2008'),'last_credit_pull_d'] = 'Q1-2008'
data_new.loc[data_new.last_credit_pull_d.str.contains('Apr-2008|May-2008|Jun-2008'),'last_credit_pull_d'] = 'Q2-2008'
data_new.loc[data_new.last_credit_pull_d.str.contains('Jul-2008|Aug-2008|Sep-2008'),'last_credit_pull_d'] = 'Q3-2008'
data_new.loc[data_new.last_credit_pull_d.str.contains('Oct-2008|Nov-2008|Dec-2008'),'last_credit_pull_d'] = 'Q4-2008'
data_new.loc[data_new.last_credit_pull_d.str.contains('Jan-2009|Feb-2009|Mar-2009'),'last_credit_pull_d'] = 'Q1-2009'
data_new.loc[data_new.last_credit_pull_d.str.contains('Apr-2009|May-2009|Jun-2009'),'last_credit_pull_d'] = 'Q2-2009'
data_new.loc[data_new.last_credit_pull_d.str.contains('Jul-2009|Aug-2009|Sep-2009'),'last_credit_pull_d'] = 'Q3-2009'
data_new.loc[data_new.last_credit_pull_d.str.contains('Oct-2009|Nov-2009|Dec-2009'),'last_credit_pull_d'] = 'Q4-2009'
data_new.loc[data_new.last_credit_pull_d.str.contains('Jan-2010|Feb-2010|Mar-2010'),'last_credit_pull_d'] = 'Q1-2010'
data_new.loc[data_new.last_credit_pull_d.str.contains('Apr-2010|May-2010|Jun-2010'),'last_credit_pull_d'] = 'Q2-2010'
data_new.loc[data_new.last_credit_pull_d.str.contains('Jul-2010|Aug-2010|Sep-2010'),'last_credit_pull_d'] = 'Q3-2010'
data_new.loc[data_new.last_credit_pull_d.str.contains('Oct-2010|Nov-2010|Dec-2010'),'last_credit_pull_d'] = 'Q4-2010'
data_new.loc[data_new.last_credit_pull_d.str.contains('Jan-2011|Feb-2011|Mar-2011'),'last_credit_pull_d'] = 'Q1-2011'
data_new.loc[data_new.last_credit_pull_d.str.contains('Apr-2011|May-2011|Jun-2011'),'last_credit_pull_d'] = 'Q2-2011'
data_new.loc[data_new.last_credit_pull_d.str.contains('Jul-2011|Aug-2011|Sep-2011'),'last_credit_pull_d'] = 'Q3-2011'
data_new.loc[data_new.last_credit_pull_d.str.contains('Oct-2011|Nov-2011|Dec-2011'),'last_credit_pull_d'] = 'Q4-2011'
data_new.loc[data_new.last_credit_pull_d.str.contains('Jan-2012|Feb-2012|Mar-2012'),'last_credit_pull_d'] = 'Q1-2012'
data_new.loc[data_new.last_credit_pull_d.str.contains('Apr-2012|May-2012|Jun-2012'),'last_credit_pull_d'] = 'Q2-2012'
data_new.loc[data_new.last_credit_pull_d.str.contains('Jul-2012|Aug-2012|Sep-2012'),'last_credit_pull_d'] = 'Q3-2012'
data_new.loc[data_new.last_credit_pull_d.str.contains('Oct-2012|Nov-2012|Dec-2012'),'last_credit_pull_d'] = 'Q4-2012'
data_new.loc[data_new.last_credit_pull_d.str.contains('Jan-2013|Feb-2013|Mar-2013'),'last_credit_pull_d'] = 'Q1-2013'
data_new.loc[data_new.last_credit_pull_d.str.contains('Apr-2013|May-2013|Jun-2013'),'last_credit_pull_d'] = 'Q2-2013'
data_new.loc[data_new.last_credit_pull_d.str.contains('Jul-2013|Aug-2013|Sep-2013'),'last_credit_pull_d'] = 'Q3-2013'
data_new.loc[data_new.last_credit_pull_d.str.contains('Oct-2013|Nov-2013|Dec-2013'),'last_credit_pull_d'] = 'Q4-2013'
data_new.loc[data_new.last_credit_pull_d.str.contains('Jan-2014|Feb-2014|Mar-2014'),'last_credit_pull_d'] = 'Q1-2014'
data_new.loc[data_new.last_credit_pull_d.str.contains('Apr-2014|May-2014|Jun-2014'),'last_credit_pull_d'] = 'Q2-2014'
data_new.loc[data_new.last_credit_pull_d.str.contains('Jul-2014|Aug-2014|Sep-2014'),'last_credit_pull_d'] = 'Q3-2014'
data_new.loc[data_new.last_credit_pull_d.str.contains('Oct-2014|Nov-2014|Dec-2014'),'last_credit_pull_d'] = 'Q4-2014'
data_new.loc[data_new.last_credit_pull_d.str.contains('Jan-2015|Feb-2015|Mar-2015'),'last_credit_pull_d'] = 'Q1-2015'
data_new.loc[data_new.last_credit_pull_d.str.contains('Apr-2015|May-2015|Jun-2015'),'last_credit_pull_d'] = 'Q2-2015'
data_new.loc[data_new.last_credit_pull_d.str.contains('Jul-2015|Aug-2015|Sep-2015'),'last_credit_pull_d'] = 'Q3-2015'
data_new.loc[data_new.last_credit_pull_d.str.contains('Oct-2015|Nov-2015|Dec-2015'),'last_credit_pull_d'] = 'Q4-2015'
data_new.loc[data_new.last_credit_pull_d.str.contains('Jan-2016|Feb-2016|Mar-2016'),'last_credit_pull_d'] = 'Q1-2016'
data_new.loc[data_new.last_credit_pull_d.str.contains('Apr-2016|May-2016|Jun-2016'),'last_credit_pull_d'] = 'Q2-2016'
data_new.loc[data_new.last_credit_pull_d.str.contains('Jul-2016|Aug-2016|Sep-2016'),'last_credit_pull_d'] = 'Q3-2016'
data_new.loc[data_new.last_credit_pull_d.str.contains('Oct-2016|Nov-2016|Dec-2016'),'last_credit_pull_d'] = 'Q4-2016'
#It's very important to reassign the data_num/cat with the updated data_new records
data_num = data_new.select_dtypes(include=numerics)
data_cat = data_new.select_dtypes(include=categories)
# print(data_new.last_credit_pull_d.value_counts())

# # issue_d
data_new.loc[data_new.issue_d.str.contains('Jan-2007|Feb-2007|Mar-2007|Apr-2007|May-2007|Jun-2007|Jul-2007|Aug-2007|Sep-2007|Oct-2007|Nov-2007|Dec-2007|Jan-2008|Feb-2008|Mar-2008|Apr-2008|May-2008|Jun-2008|Jul-2008|Aug-2008|Sep-2008|Oct-2008|Nov-2008|Dec-2008|Jan-2009|Feb-2009|Mar-2009|Apr-2009|May-2009|Jun-2009|Jul-2009|Aug-2009|Sep-2009|Oct-2009|Nov-2009|Dec-2009|Jan-2010|Feb-2010|Mar-2010|Apr-2010|May-2010|Jun-2010|Jul-2010|Aug-2010|Sep-2010|Oct-2010|Nov-2010|Dec-2010|Jan-2011|Feb-2011|Mar-2011|Apr-2011|May-2011|Jun-2011|Jul-2011|Aug-2011|Sep-2011|Oct-2011|Nov-2011|Dec-2011|Jan-2012|Feb-2012|Mar-2012|Apr-2012|May-2012|Jun-2012|Jul-2012|Aug-2012|Sep-2012|Oct-2012|Nov-2012|Dec-2012|Jan-2013|Feb-2013|Mar-2013|Apr-2013|May-2013|Jun-2013|Jul-2013|Aug-2013|Sep-2013|Oct-2013|Nov-2013|Dec-2013|Jan-2014|Feb-2014|Mar-2014|Apr-2014|May-2014|Jun-2014|Jul-2014|Aug-2014|Sep-2014|Oct-2014|Nov-2014|Dec-2014|Jan-2015|Feb-2015|Mar-2015|Apr-2015|May-2015|Jun-2015'),'issue_d'] = 'Train'
data_new.loc[data_new.issue_d.str.contains('Jul-2015|Aug-2015|Sep-2015|Oct-2015|Nov-2015|Dec-2015|Jan-2016|Feb-2016|Mar-2016|Apr-2016|May-2016|Jun-2016|Jul-2016|Aug-2016|Sep-2016|Oct-2016|Nov-2016|Dec-2016'),'issue_d'] ='Test'
#It's very important to reassign the data_num/cat with the updated data_new records
data_num = data_new.select_dtypes(include=numerics)
data_cat = data_new.select_dtypes(include=categories)
print(data_new.issue_d.value_counts())
# Out:
# Train    626030
# Test     221001
# Name: issue_d, dtype: int64

# %%
data_cat.head()
# Out:
#   home_ownership issue_d         purpose           title addr_state  \
# 0           RENT   Train     credit_card  Other_expenses       West
# 1           RENT   Train             car  Other_expenses      South
# 2           RENT   Train  small_business  Other_expenses   Mid_west
# 3           RENT   Train           other  Other_expenses       West
# 4           RENT   Train           other  Other_expenses       West
#
#   earliest_cr_line initial_list_status last_pymnt_d next_pymnt_d  \
# 0          1980-99                   f      Q1-2015      Unknown
# 1          1980-99                   f      Q2-2013      Unknown
# 2          2000-05                   f      Q2-2014      Unknown
# 3          1980-99                   f      Q1-2015      Unknown
# 4          1980-99                   f      Q1-2016     Feb-2016
#
#   last_credit_pull_d application_type default_ind
# 0            Q1-2016       INDIVIDUAL           0
# 1            Q3-2013       INDIVIDUAL           1
# ...

# %%
Unique_value_counts(data_cat)
# Out:
#                   Field  Counts
# 1               issue_d       2
# 6   initial_list_status       2
# 10     application_type       2
# 11          default_ind       2
# 0        home_ownership       4
# 4            addr_state       4
# 8          next_pymnt_d       4
# 3                 title       6
# 5      earliest_cr_line       6
# 2               purpose      14
# 7          last_pymnt_d      33
# 9    last_credit_pull_d      36

# %%
print('Shape of Num data Before moving/altering features: ',data_num.shape)
print('Shape of cat data Before moving/altering features: ',data_cat.shape)

#It's very important to reassign the data_num/cat with the updated data_new records
data_num = data_new.select_dtypes(include=numerics)
data_cat = data_new.select_dtypes(include=categories)

data_num.to_csv('Significant_Numerical_features_aggregated_version.csv')
data_cat.to_csv('Significant_Categorical_features_aggregated_version.csv')
print('Files are written to Local successfully')

data_num = pd.read_csv('Significant_Numerical_features_aggregated_version.csv')
data_cat = pd.read_csv('Significant_Categorical_features_aggregated_version.csv')

data_cat.drop(labels='Unnamed: 0', axis=1, inplace=True)
data_num.drop(labels='Unnamed: 0', axis=1, inplace=True)

print('Shape after moving/altering features: ',data_num.shape)
print('Shape of cat data after moving/altering features: ',data_cat.shape)
# Out:
# Shape of Num data Before moving/altering features:  (847031, 26)
# Shape of cat data Before moving/altering features:  (847031, 12)
# Files are written to Local successfully
# Shape after moving/altering features:  (847031, 26)
# Shape of cat data after moving/altering features:  (847031, 12)

# %%
data_cat = data_new.select_dtypes(include=categories)

# %%
data_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847031 entries, 0 to 847030
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   loan_amnt                847031 non-null  float64
#  1   funded_amnt              847031 non-null  float64
#  2   funded_amnt_inv          847031 non-null  float64
#  3   term                     847031 non-null  float64
#  4   int_rate                 847031 non-null  float64
#  5   installment              847031 non-null  float64
#  6   grade                    847031 non-null  float64
#  7   sub_grade                847031 non-null  float64
#  8   emp_length               847031 non-null  float64
#  9   annual_inc               847031 non-null  float64
#  10  verification_status      847031 non-null  float64
#  11  dti                      847031 non-null  float64
#  12  delinq_2yrs              847031 non-null  float64
# ...

# %%
data_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847031 entries, 0 to 847030
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   home_ownership       847031 non-null  object
#  1   issue_d              847031 non-null  object
#  2   purpose              847031 non-null  object
#  3   title                847031 non-null  object
#  4   addr_state           847031 non-null  object
#  5   earliest_cr_line     847031 non-null  object
#  6   initial_list_status  847031 non-null  object
#  7   last_pymnt_d         847031 non-null  object
#  8   next_pymnt_d         847031 non-null  object
#  9   last_credit_pull_d   847031 non-null  object
#  10  application_type     847031 non-null  object
#  11  default_ind          847031 non-null  object
# dtypes: object(12)
# memory usage: 77.5+ MB

# %%
Unique_value_counts(data_cat)
# Out:
#                   Field  Counts
# 1               issue_d       2
# 6   initial_list_status       2
# 10     application_type       2
# 11          default_ind       2
# 0        home_ownership       4
# 4            addr_state       4
# 8          next_pymnt_d       4
# 3                 title       6
# 5      earliest_cr_line       6
# 2               purpose      14
# 7          last_pymnt_d      33
# 9    last_credit_pull_d      36

# %%
Final_data = pd.concat([data_num,data_cat], axis=1, ignore_index=False)
Final_data.default_ind = Final_data.default_ind.astype('float64')
Final_data.shape
# Out:
# (847031, 38)

# %%
Final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847031 entries, 0 to 847030
# Data columns (total 38 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   loan_amnt                847031 non-null  float64
#  1   funded_amnt              847031 non-null  float64
#  2   funded_amnt_inv          847031 non-null  float64
#  3   term                     847031 non-null  float64
#  4   int_rate                 847031 non-null  float64
#  5   installment              847031 non-null  float64
#  6   grade                    847031 non-null  float64
#  7   sub_grade                847031 non-null  float64
#  8   emp_length               847031 non-null  float64
#  9   annual_inc               847031 non-null  float64
#  10  verification_status      847031 non-null  float64
#  11  dti                      847031 non-null  float64
#  12  delinq_2yrs              847031 non-null  float64
# ...

# %%
# Unique_value_counts(Final_data)
print(Final_data.default_ind.value_counts())
print(Final_data.application_type.value_counts())
print(Final_data.issue_d.value_counts())
print(Final_data.term.value_counts())
print(Final_data.initial_list_status.value_counts())
# Out:
# 0.0    801108
# 1.0     45923
# Name: default_ind, dtype: int64
# INDIVIDUAL    846660
# JOINT            371
# Name: application_type, dtype: int64
# Train    626030
# Test     221001
# Name: issue_d, dtype: int64
# 36.0    594090
# 60.0    252941
# Name: term, dtype: int64
# f    440848
# w    406183
# Name: initial_list_status, dtype: int64

# %% [markdown]
# ### One-Hot encoding for rest of the categorical variables

# %%
print('Shape after before dummies: ', Final_data.shape)
Final_data = pd.get_dummies(Final_data,drop_first=True)
Final_data.to_csv('Final_data.csv')
print('File saved to local successfully')
Final_data= pd.read_csv('Final_data.csv')
Final_data.drop(labels='Unnamed: 0', axis=1, inplace=True)
print('Shape after creating dummies: ', Final_data.shape)
# Out:
# Shape after before dummies:  (847031, 38)
# File saved to local successfully
# Shape after creating dummies:  (847031, 130)
